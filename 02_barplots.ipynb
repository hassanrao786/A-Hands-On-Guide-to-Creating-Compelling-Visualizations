# %% [markdown]
# ## Bar plots

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
phool = sns.load_dataset("iris")
phool
sns.barplot(x="species",y="sepal_width",data =phool)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue= "who",data =kashti)
# Out:
# <Axes: xlabel='sex', ylabel='alone'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue= "who",data =kashti,order=['female',"male"])
# Out:
# <Axes: xlabel='sex', ylabel='alone'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue= "who",data =kashti,order=['female',"male"])
# Out:
# <Axes: xlabel='sex', ylabel='alone'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue= "who",data =kashti,color="red")     # grey,red,blue     # color paletts
# Out:
# <Axes: xlabel='sex', ylabel='alone'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue= "who",data =kashti,color="yellow",ci=None) # error bar removal
plt.show
# Out:
# C:\Users\Al Makkah\AppData\Local\Temp\ipykernel_7668\2718739443.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex",y="alone",hue= "who",data =kashti,color="yellow",ci=None) # error bar removal
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue= "who",data =kashti,color="yellow",ci=None,
           palette="coolwarm")
plt.show
# Out:
# C:\Users\Al Makkah\AppData\Local\Temp\ipykernel_7668\3524597612.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex",y="alone",hue= "who",data =kashti,color="yellow",ci=None,
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns
from numpy  import median
import matplotlib.pyplot as plt

# #load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="class", y="fare", hue="sex" , data=kashti ,estimator=median)
plt.show()

# %%
import seaborn as sns
from numpy  import mean
import matplotlib.pyplot as plt

# #load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="class", y="fare", hue="sex" , data=kashti ,estimator=mean, saturation=0.8)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
#horizantal plot

# %%
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="fare", y="class", hue="sex" , data=kashti ,estimator=median)
plt.show()

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

#load data set
kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="class", y="fare", data=kashti,
           linewidth=8,facecolor=(1,0.0,0.0,0.9),               # RGBA
           errcolor="0.5",edgecolor="0.3")
# Out:
# <Axes: xlabel='class', ylabel='fare'>
