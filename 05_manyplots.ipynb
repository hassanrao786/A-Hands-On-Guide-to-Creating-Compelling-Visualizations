# %% [markdown]
# # Data  visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# importing a dataset
kashti=sns.load_dataset("titanic")

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # How many null values in our data

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# how to make a bar plot
kashti.survived.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(x="survived",hue="sex" ,data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.scatterplot(x="age",y="fare",hue="pclass",data= kashti)             # age fare numeric # pclsss category
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data=kashti,x="sex",y="fare",hue="pclass")    # not  a scattered plot
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(data=kashti,x="sex",y="fare",hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.pairplot(kashti)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
kashti.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.hist(bins=20,figsize=(9,8))
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.hist(bins=10,figsize=(9,8),grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(data=kashti,x="sex",y="fare",hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxplot(data=kashti,x="sex",y="fare",hue="parch")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxplot(data=kashti,x="sex",y="fare",hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashti,x="sex",y="fare",hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# assignment 
# how to change title x azis and y axiz

# %%
a=sns.FacetGrid(kashti,hue="survived",col="pclass",margin_titles=True,
                 palette={1:"seagreen",0:"red"})

a=a.map(plt.scatter,"fare","age",edgecolor="w").add_legend()

# %%
sns.stripplot(data=kashti,x="sex",y="fare",hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# strip plot is a combination of bar plot and  scater plot
sns.stripplot(data=kashti,x="sex",y="fare",hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# data varaible name assign kia hy titanic ko yha

data = sns.load_dataset("titanic")
data.replace('No', np.nan, inplace=True)  # Replace 'No' with NaN
data.dropna(inplace=True)  # Drop rows with missing values

numeric_data = data.select_dtypes(include=np.number)  # Select only numeric columns

corr = numeric_data.corr()
corr
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.037698 -0.251045  0.101376  0.018739  0.130632
# pclass   -0.037698  1.000000 -0.305708 -0.105262  0.046273 -0.316796
# age      -0.251045 -0.305708  1.000000 -0.154160 -0.269757 -0.090730
# sibsp     0.101376 -0.105262 -0.154160  1.000000  0.253478  0.284841
# parch     0.018739  0.046273 -0.269757  0.253478  1.000000  0.388540
# fare      0.130632 -0.316796 -0.090730  0.284841  0.388540  1.000000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("titanic")
data.replace('No', np.nan, inplace=True)  # Replace 'No' with NaN
data.dropna(inplace=True)  # Drop rows with missing values

numeric_data = data.select_dtypes(include=np.number)  # Select only numeric columns

corr = numeric_data.corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.violinplot(data=kashti,x="sex",y="fare",hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")
